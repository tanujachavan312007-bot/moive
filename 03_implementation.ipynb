# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('final_data.csv')

# %%
#DTM - Word Count Matrix
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=10000, stop_words = 'english')
dtm = cv.fit_transform(df['tags'])
dtm_df = pd.DataFrame(data = dtm.toarray(),  columns = cv.get_feature_names_out())

# %%
 cv.get_feature_names_out()[101:1000]
# Out:
# array(['addison', 'addy', 'adefarasin', 'adele', 'adewale', 'adi',
#        'adiri', 'aditya', 'adkins', 'adler', 'admit', 'adolescence',
#        'adolescent', 'adolf', 'adonis', 'adopt', 'adoption', 'adrian',
#        'adriana', 'adriano', 'adrien', 'adrienne', 'adruitha', 'adult',
#        'adultery', 'adulthood', 'advantage', 'adventure', 'advertising',
#        'advice', 'affair', 'affect', 'affection', 'affleck',
#        'afghanistan', 'afraid', 'africa', 'african', 'africanamerican',
#        'aftercreditsstinger', 'afterlife', 'afterman', 'aftermath', 'ag',
#        'agbaje', 'age', 'agency', 'agenda', 'agent', 'aggie',
#        'aggression', 'aggressive', 'aghdashloo', 'agnes', 'agnès', 'ago',
#        'agree', 'aguilar', 'aguirre', 'aguirresarobe', 'ahead', 'ahern',
#        'ahmad', 'ahmed', 'ai', 'aibel', 'aid', 'aida', 'aidan', 'aiello',
#        'ail', 'aim', 'aimee', 'air', 'airplane', 'airport', 'aisha',
#        'aitken', 'aj', 'aja', 'aka', 'akander', 'akinnuoye', 'akira',
#        'akiva', 'al', 'alain', 'alan', 'alana', 'alanna', 'alaska',
#        'alastair', 'alazraqui', 'alba', 'albert', 'alberta', 'alberti',
#        'alberto', 'albertson', 'albrecht', 'alcohol', 'alcoholic',
#        'alcoholism', 'alcon', 'alda', 'alden', 'aldo', 'aldredge',
#        'aldridge', 'alec', 'alejandro', 'aleksandr', 'aleksey',
#        'alessandra', 'alessandro', 'alex', 'alexa', 'alexander',
#        'alexandra', 'alexandre', 'alexia', 'alexis', 'alf', 'alfie',
#        'alfieri', 'alfonso', 'alfre', 'alfred', 'alfredo', 'ali', 'alia',
#        'alice', 'alicia', 'alien', 'alike', 'alina', 'aline', 'alisa',
#        'alison', 'alistair', 'alive', 'alix', 'allain', 'allan', 'allday',
#        'allegra', 'allen', 'alley', 'alliance', 'allie', 'allied',
#        'allison', 'allmark', 'allon', 'allow', 'ally', 'alma', 'almeida',
#        'alongside', 'alonso', 'alonzo', 'alper', 'alpert', 'alpha',
#        'alphaville', 'alter', 'alternate', 'alternative', 'altman',
#        'alun', 'alvarado', 'alvarez', 'alverson', 'alves', 'alvin',
#        'alyn', 'alyson', 'alyssa', 'alzheimer', 'amador', 'amanda',
#        'amateau', 'amateur', 'amato', 'amazing', 'amazon', 'ambassador',
#        'amber', 'ambition', 'ambitious', 'amblin', 'ambrose', 'ambulance',
#        'ambush', 'amelia', 'america', 'american', 'americans', 'ames',
#        'ami', 'amico', 'amidst', 'amin', 'amir', 'amnesia', 'amos', 'amp',
#        'amritraj', 'amundsen', 'amundson', 'amusement', 'amy', 'ana',
#        'analyst', 'anand', 'anarchic', 'anastas', 'anastasia', 'anaya',
#        'ancient', 'andelin', 'anders', 'andersen', 'anderson',
#        'andersson', 'andi', 'andie', 'andra', 'andrade', 'andre',
#        'andrea', 'andreas', 'andrei', 'andres', 'andrew', 'andrews',
#        'andrey', 'android', 'andrus', 'andrzej', 'andré', 'andrés',
#        'andy', 'ang', 'angarano', 'angel', 'angela', 'angeles', 'angelic',
#        'angelica', 'angelina', 'angelis', 'angelo', 'anger', 'angerio',
#        'angie', 'angry', 'angus', 'anil', 'animal', 'animate',
#        'animation', 'aniston', 'anita', 'anja', 'anjelica', 'anji', 'ann',
#        'anna', 'annabel', 'annabelle', 'annable', 'annasophia', 'anne',
#        'annette', 'annie', 'annika', 'anniversary', 'announce', 'annual',
#        'anonymous', 'anozie', 'ansari', 'ansell', 'anson', 'answer',
#        'anthology', 'anthony', 'anthropomorphism', 'anti', 'antic',
#        'antoine', 'antoinette', 'anton', 'antoni', 'antonia', 'antonio',
#        'antony', 'anwar', 'anya', 'aoki', 'apart', 'apartment', 'apatow',
#        'ape', 'apocalypse', 'apocalyptic', 'apollo', 'apone', 'appear',
#        'appearance', 'appel', 'apple', 'appleby', 'applegate', 'appoint',
#        'apprentice', 'approach', 'april', 'apted', 'aquila', 'aquino',
#        'arab', 'arad', 'aradóttir', 'arana', 'aravind', 'arbegast',
#        'arbogast', 'archaeologist', 'archer', 'archibald', 'archie',
#        'architect', 'arcy', 'arden', 'area', 'arena', 'ari', 'ariana',
#        'ariane', 'arianne', 'arias', 'ariel', 'arielle', 'arise',
#        'aristocrat', 'arkin', 'arlen', 'arlene', 'arliss', 'arm',
#        'armand', 'armando', 'armed', 'armen', 'armin', 'armisen',
#        'armitage', 'arms', 'armstrong', 'army', 'armyan', 'arnaud',
#        'arndt', 'arne', 'arnett', 'arnold', 'arnon', 'aron', 'aronofsky',
#        'aronowitz', 'aronson', 'arquette', 'arrange', 'arranged',
#        'arrest', 'arrival', 'arrive', 'arrow', 'art', 'arte', 'arthur',
#        'article', 'artie', 'artificial', 'artisan', 'artist', 'artists',
#        'arts', 'arturo', 'artz', 'arun', 'aruna', 'arvinder', 'asa',
#        'asbury', 'ash', 'ashby', 'asher', 'ashford', 'ashleigh', 'ashley',
#        'ashmore', 'ashok', 'ashton', 'ashwill', 'asia', 'ask', 'askew',
#        'asman', 'aspect', 'aspiration', 'aspire', 'aspiring', 'assassin',
#        'assassinate', 'assassination', 'assault', 'assells', 'assemble',
#        'assign', 'assignment', 'assistant', 'associate', 'assume',
#        'asteroid', 'astin', 'astronaut', 'asylum', 'ateah', 'atherton',
#        'athlete', 'atkin', 'atkins', 'atkinson', 'atlantic', 'atlantis',
#        'atlas', 'atmajian', 'atmosphere', 'ato', 'atomic', 'atsushi',
#        'attack', 'attempt', 'attempted', 'attenborough', 'attend',
#        'attention', 'atticus', 'attila', 'attitude', 'attorney',
#        'attract', 'attraction', 'attractive', 'atwell', 'atwood', 'au',
#        'aubrey', 'audience', 'audition', 'audouy', 'audra', 'audrey',
#        'audsley', 'augie', 'august', 'auguste', 'augusto', 'aulicino',
#        'aulisi', 'aunjanue', 'aunt', 'aurora', 'austen', 'austerberry',
#        'austin', 'australia', 'australian', 'author', 'authority', 'auto',
#        'automobile', 'autumn', 'ava', 'avellan', 'avenge', 'average',
#        'avery', 'avi', 'avila', 'avoid', 'avy', 'await', 'awaken',
#        'award', 'away', 'awry', 'axel', 'axelrad', 'ayer', 'ayers',
#        'aykroyd', 'aylward', 'azaria', 'aziz', 'ba', 'babcock',
#        'babelsberg', 'baby', 'baca', 'bacall', 'bach', 'bachchan',
#        'bachelor', 'backdrop', 'background', 'backup', 'bacon', 'bad',
#        'badalamenti', 'badalato', 'badami', 'baddeley', 'badelt', 'bader',
#        'badge', 'baer', 'bag', 'bagley', 'bahr', 'bai', 'bail', 'bailey',
#        'bailie', 'bain', 'baine', 'baird', 'baker', 'balaban', 'balance',
#        'baldi', 'baldwin', 'bale', 'balfe', 'balfour', 'ball', 'ballard',
#        'ballet', 'ballhaus', 'balsam', 'baltimore', 'bamford', 'ban',
#        'bana', 'bancroft', 'band', 'banderas', 'bangera', 'banish',
#        'bank', 'banker', 'banks', 'banner', 'bannister', 'bannon',
#        'bansal', 'baptiste', 'bar', 'baranski', 'barba', 'barbanell',
#        'barbara', 'barber', 'barclay', 'bard', 'bardem', 'barden',
#        'barek', 'barely', 'bargain', 'bargen', 'barius', 'barker',
#        'barkin', 'barlow', 'barn', 'barnaby', 'barnard', 'barnathan',
#        'barnes', 'barnett', 'barney', 'baron', 'barr', 'barrera',
#        'barrett', 'barrie', 'barrier', 'barron', 'barry', 'barrymore',
#        'bart', 'bartek', 'barth', 'bartholomew', 'bartkowiak', 'bartlett',
#        'barton', 'baruchel', 'base', 'baseball', 'based', 'basement',
#        'basil', 'basile', 'basinger', 'basketball', 'baskin', 'bass',
#        'bassett', 'bat', 'bateman', 'bates', 'batman', 'battaglia',
#        'battle', 'battlefield', 'bauchau', 'bauer', 'baugh', 'baum',
#        'baumgarten', 'bautista', 'baverstock', 'bax', 'baxley', 'baxter',
#        'bay', 'bbc', 'bc', 'beach', 'beacon', 'beal', 'beale', 'bean',
#        'bear', 'beard', 'beardwood', 'beasley', 'beast', 'beat', 'beaton',
#        'beatrice', 'beatrix', 'beattie', 'beatty', 'beau', 'beauchamp',
#        'beautiful', 'beauty', 'beavan', 'beaver', 'bebe', 'becca', 'beck',
#        'becker', 'beckett', 'becki', 'beckinsale', 'becky', 'bed',
#        'bedard', 'bedford', 'bee', 'beebe', 'beemer', 'beer', 'befriend',
#        'beggs', 'begin', 'beginning', 'begley', 'behavior', 'behlmer',
#        'beijing', 'bel', 'belasco', 'belcher', 'belgardt', 'belief',
#        'believe', 'belinda', 'bell', 'bella', 'bellamy', 'belle',
#        'bellew', 'bellfort', 'bello', 'bellucci', 'belong', 'beloved',
#        'beltrami', 'belushi', 'belén', 'bemben', 'ben', 'benavente',
#        'bend', 'bender', 'benderspink', 'beneath', 'benedict', 'benefit',
#        'benicio', 'bening', 'benita', 'benitez', 'benito', 'benjamin',
#        'benjamín', 'bennett', 'benny', 'benoit', 'benoît', 'benson',
#        'bent', 'bentley', 'benton', 'benvenuti', 'berardi', 'berdan',
#        'berenger', 'berenson', 'beresford', 'berg', 'bergen', 'berger',
#        'bergeron', 'bergin', 'bergman', 'beristain', 'berkeley', 'berkey',
#        'berlin', 'berman', 'bernadette', 'bernal', 'bernard', 'bernardi',
#        'bernardo', 'bernd', 'berner', 'bernhard', 'bernie', 'bernier',
#        'bernstein', 'bernthal', 'berry', 'berryman', 'bert', 'bertrand',
#        'bess', 'besser', 'besson', 'best', 'bestrop', 'bestselle', 'bet',
#        'betancourt', 'beth', 'bethany', 'betray', 'betrayal', 'betsy',
#        'bettany', 'bette', 'bettina', 'betts', 'betty', 'bevan',
#        'beveridge', 'beverley', 'beverly', 'beville', 'bey', 'beyda',
#        'beyer', 'bianca', 'bibb', 'bible', 'bickerton', 'biddle', 'biehn',
#        'biel', 'big', 'biggs', 'bike', 'biker', 'bikini', 'bilcock',
#        'bille', 'billie', 'billingsley', 'billington', 'billionaire',
#        'billy', 'bin', 'bind', 'binder', 'bing', 'bingham', 'biography',
#        'biological', 'birch', 'bird', 'birgit', 'birmingham', 'birnbaum',
#        'birth', 'birthday', 'biscoe', 'bisexual', 'bishop', 'bissell',
#        'bisson', 'bit', 'bite', 'bitter', 'bittner', 'bizarre', 'bjerno',
#        'bjorn', 'björn', 'black', 'blackburn', 'blackmail', 'blackman',
#        'blackwell', 'blackwood', 'blade', 'blades', 'blaine', 'blair',
#        'blaise', 'blake', 'blame', 'blanc', 'blanchard', 'blanche',
#        'blanchett', 'blanco', 'blanford', 'blank', 'blankenship', 'blaze',
#        'bledel', 'bleibtreu', 'blend', 'blessed', 'bleu', 'blevins',
#        'blind', 'blindness', 'bliss', 'bloch', 'block', 'blonde',
#        'blondell', 'blood', 'bloodthirsty', 'bloody', 'bloom',
#        'bloomfield', 'blossom', 'blow', 'blucas', 'blue', 'blum',
#        'blumenfeld', 'blumenthal', 'blumhouse', 'blunden', 'blunt',
#        'blythe', 'bo', 'board', 'boarding', 'boardman', 'boat', 'boaz',
#        'bob', 'bobbie', 'bobbitt', 'bobby', 'boccia'], dtype=object)

# %%
#Lets calculate cosine similarity - movie relationship in percentage
from sklearn.metrics.pairwise import cosine_similarity
similarities = cosine_similarity(dtm_df)

# %%
#similarities[0]
#df

# %%
def get_movie_index(name):
    for i in df.index:
        if name == df.loc[i, 'title']:
            return i
    else:
        return -1

def get_movie_name(i):
    if i > len(df):
        return ""
    else:
        return df.loc[i, 'title']

# %%
name = input("Enter movie name you watched:")
index = get_movie_index(name)
if index == -1:
    print("Sorry, movie not found")
else:
    similarity_index = similarities[index]
    similarity_index = list(enumerate(similarity_index))
    similarity_index = sorted(similarity_index, key = lambda x:x[1], reverse = True)
    print("Predicted next 5 movies")
    for i in range(1, 6):
        print(str(i) + ". " + get_movie_name(similarity_index[i][0]))
# Out:
# Enter movie name you watched: Harry Potter and the Prisoner of Azkaban Predicted next 5 movies
# Sorry, movie not found

# %%
#Lets save similarities as pickle file
import pickle
pickle.dump(similarities, open('similarities.pkl', 'wb'))
